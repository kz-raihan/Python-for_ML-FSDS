# %% [markdown]
# ## Practices of Loops

# %% [markdown]
# ### Questions?
#
# 🔴 ADVANCED LOOP QUESTIONS (Level 4)
#
# - 1️⃣ Print all prime numbers between 1 to 200
#
# - 2️⃣ Check if a number is an Armstrong number
#
# - 2️⃣ Check if a number is an Armstrong number
#
# - 3️⃣ Print this pattern (centered pyramid)
#
# - 4️⃣ Print this pattern (numbers pyramid)
#
# - 5️⃣ Find the factorial of a number WITHOUT using math library
#
# - 6️⃣ Print Fibonacci numbers up to N terms
#
# - 7️⃣ Print all “perfect numbers” between 1 and 1000
#
# - 8️⃣ Count digits, letters, and special characters in a given string (loop only)
#
# - 9️⃣ Reverse a string WITHOUT using slicing or reversed()
#
# - 🔟 Find the largest digit in a number
