# %% [markdown]
# ## Topic: Introduction of string

# %% [markdown]
# ### OUTCOMES
#
# - 1. Definition of string
#
# - 2. Syntax of string.

# %% [markdown]
# - Definiton of String
#
#     - String is immutable (not changeable) data type.
#
#     - String elements arranged in sequentially manner.

# %%
""" 
# Syntax of String:

   - str_name = "values" 
    
"""
