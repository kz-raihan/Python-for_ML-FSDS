# %% [markdown]
# ## Strings Functions/Methods
# - Capitalize
# - Title
# - Upper
# - Lower
# - Swapcase

# %% [markdown]
# - endswith
# - startswith

# %% [markdown]
# - Count
# - Find
# - Index

# %% [markdown]
# - isalnum
# - isalpha
# - isdigit
# - isidentifier

# %% [markdown]
# - Split
# - Join

# %% [markdown]
# - Replace
# - Strip
