# %% [markdown]
# ## Topic: String in Pytnon

# %% [markdown]
# ### OUTCOMES
#
# - 1. Introduction of String
#
# - 2. Creating String
#
# - 3. Access of String
#     - String Indexing and Slicing.
#     - String Immutablity Propertices.
#
# - 4. String Basic operation
#
# - 5. String Method
#
# - 6. Formating of String
#
# - 7. String Practices
