# %% [markdown]
# ## Topic: Introduction and Python Basic

# %% [markdown]
# ### Agenda
#
# - 1. Introduction of Python
#
# - 2. Python Data types and Comments
#
# - 3. Variables, Keywords and Identifiers
#
# - 4. Python Input and Type conversion in Python
#
# - 5. Literals in Python
#
# - 6. Operators in Python
